# %% [markdown]
# # 3. Model Testing and Inference
#
# Evaluate your trained weights, run validation metrics on your test splits, and perform visual inference.

# %%
from ultralytics import YOLO

# Path to your trained weights
best_model_path = '../Models/Safespace_Experiment/weights/best.pt'
trained_model = YOLO(best_model_path)

# %%
# Run Validation metrics on the specific dataset
data_yaml_path = r'../Datasets/your_dataset_folder/data.yaml'
# metrics = trained_model.val(data=data_yaml_path)

# %%
# Run inference on a sample image
test_image = '../bus.jpg'
# results = trained_model(test_image, save=True, show=True)
