# %% [markdown]
# # 2. Model Training
#
# Train the `yolov8n.pt` model on any of your datasets. Update `data_yaml_path` to the target dataset you want to use.

# %%
from ultralytics import YOLO
import torch

# Load the YOLOv8 Nano model as requested
model = YOLO('yolov8n.pt')

# Path to your specific dataset's data.yaml
data_yaml_path = r'../Datasets/your_dataset_folder/data.yaml'

TRAINING_CONFIG = {
    'data': data_yaml_path,
    'epochs': 40,
    'batch': 16,
    'imgsz': 640,
    'device': 0 if torch.cuda.is_available() else 'cpu',
    'workers': 8,
    'patience': 20,
    'save': True,
    'project': '../Models',
    'name': 'Safespace_Experiment',
    'exist_ok': True,
    'pretrained': True,
}

# %%
# RUN TRAINING
# Uncomment the line below to start the training process
# results = model.train(**TRAINING_CONFIG)
